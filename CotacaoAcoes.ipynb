# %% [markdown]
# <a href="https://colab.research.google.com/github/angeruzzi/TestesENotas/blob/main/CotacaoAcoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas_datareader import data as web
import matplotlib.pyplot as plt

df = web.DataReader(f'PETR4.SA', data_source='yahoo', start=f'05-20-2020', end='05-20-2021')
df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2020-05-20  19.440001  19.059999  19.090000  19.299999  74595100.0  18.671219
# 2020-05-21  19.770000  19.070000  19.500000  19.190001  81327000.0  18.564804
# 2020-05-22  18.900000  18.350000  18.799999  18.670000  71259400.0  18.061745
# 2020-05-25  19.559999  19.260000  19.480000  19.480000  38033000.0  18.845354
# 2020-05-26  20.090000  19.330000  19.980000  19.670000  68716900.0  19.029165

# %%
df["Adj Close"].plot(figsize=(15,10))
plt.show()
